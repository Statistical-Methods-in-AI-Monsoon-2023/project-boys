# %%
import pandas as pd
import numpy as np
import os

# %%
# Path to the folder containing CSV files
folder_path = "data/"

# Initialize an empty list to store DataFrames
dfs = []

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        # Read each CSV file into a DataFrame
        df = pd.read_csv(file_path)
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df.drop(columns=['author', 'date', 'post'], inplace=True)

# %%
# from the combined_df, create a new dataframe in which the 'subreddit' column has only the values 'addiction', 'adhd', 'alcoholism', 'anxiety', 'autism', 'bpd', 'depression', 'lonely', 'ptsd', 'schizophrenia', 'suicidewatch'. Name this new dataframe as 'new_df'
combined_df = combined_df[combined_df['subreddit'].isin(['addiction', 'adhd', 'alcoholism', 'anxiety', 'autism', 'bpd', 'depression', 'lonely', 'ptsd', 'schizophrenia', 'suicidewatch'])]

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

combined_df = pd.read_csv('./combined_df.csv')

# Encode the 'subreddit' column using label encoding
label_encoder = OneHotEncoder()
combined_df['subreddit_encoded'] = label_encoder.fit_transform(combined_df['subreddit'])

# Calculate the correlation of each column with 'subreddit_encoded'
correlation_with_subreddit = {}
for column in combined_df.columns:
    if column != 'subreddit':
        correlation = combined_df['subreddit_encoded'].corr(combined_df[column])
        correlation_with_subreddit[column] = correlation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb Cell 5 line 8
#       <a href='vscode-notebook-cell:/Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> # Encode the 'subreddit' column using label encoding
#       <a href='vscode-notebook-cell:/Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> label_encoder = OneHotEncoder()
# ----> <a href='vscode-notebook-cell:/Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> combined_df['subreddit_encoded'] = label_encoder.fit_transform(combined_df['subreddit'])
#      <a href='vscode-notebook-cell:/Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> # Calculate the correlation of each column with 'subreddit_encoded'
#      <a href='vscode-notebook-cell:/Users/yeetusonthefetus/iiit/SMAI/project-boys/main2.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> correlation_with_subreddit = {}
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/base.py:916, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     912 # non-optimized default implementation; override when a better
#     913 # method is possible for a given clustering algorithm
#     914 if y is None:
#     915     # fit method of arity 1 (unsupervised transformation)
# --> 916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
#     919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:985, in OneHotEncoder.fit(self, X, y)
#     975     warnings.warn(
#     976         (
#     977             "`sparse` was renamed to `sparse_output` in version 1.2 and "
#    (...)
#     981         FutureWarning,
#     982     )
#     983     self.sparse_output = self.sparse
# --> 985 self._fit(
#     986     X,
#     987     handle_unknown=self.handle_unknown,
#     988     force_all_finite="allow-nan",
#     989 )
#     990 self._set_drop_idx()
#     991 self._n_features_outs = self._compute_n_features_outs()
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:78, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#      76 self._check_n_features(X, reset=True)
#      77 self._check_feature_names(X, reset=True)
# ---> 78 X_list, n_samples, n_features = self._check_X(
#      79     X, force_all_finite=force_all_finite
#      80 )
#      81 self.n_features_in_ = n_features
#      83 if self.categories != "auto":
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:44, in _BaseEncoder._check_X(self, X, force_all_finite)
#      31 """
#      32 Perform custom check_array:
#      33 - convert list of strings to object dtype
#    (...)
#      40
#      41 """
#      42 if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      43     # if not a dataframe, do normal check_array validation
# ---> 44     X_temp = check_array(X, dtype=None, force_all_finite=force_all_finite)
#      45     if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      46         X = check_array(X, dtype=object, force_all_finite=force_all_finite)
#
# File ~/iiit/SMAI/project-boys/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:938, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
# --> 938         raise ValueError(
#     939             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     940             "Reshape your data either using array.reshape(-1, 1) if "
#     941             "your data has a single feature or array.reshape(1, -1) "
#     942             "if it contains a single sample.".format(array)
#     943         )
#     945 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     946     raise ValueError(
#     947         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     948         "Convert your data to numeric values explicitly instead."
#     949     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['adhd' 'adhd' 'adhd' ... 'addiction' 'addiction' 'addiction'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# Convert the correlation dictionary into a DataFrame
correlation_df = pd.DataFrame(list(correlation_with_subreddit.items()), columns=['Column', 'Correlation'])

# Sort the DataFrame by correlation values in descending order
correlation_df = correlation_df.sort_values(by='Correlation', ascending=False)

# print the correlation_df without truncation of rows
pd.set_option('display.max_rows', None)
print(correlation_df)
# Out:
#                           Column  Correlation
# 346            subreddit_encoded     1.000000
# 17                      sent_neg     0.257640
# 301                 tfidf_suicid     0.257270
# 206                   tfidf_kill     0.243008
# 145                    tfidf_die     0.204068
# 328                   tfidf_want     0.183635
# 109                 tfidf_anymor     0.173392
# 46                    liwc_death     0.172362
# 214                   tfidf_life     0.171300
# 217                   tfidf_live     0.168835
# 79                  liwc_sadness     0.147013
# 157                    tfidf_end     0.132902
# 26             suicidality_total     0.131850
# 177                   tfidf_fuck     0.128028
# 81                   liwc_sexual     0.127229
# 176                 tfidf_friend     0.127179
# 131                   tfidf_care     0.121360
# 166                 tfidf_famili     0.114730
# 22               isolation_total     0.110676
# 52                  liwc_friends     0.110039
# 84              liwc_swear_words     0.107678
# 34                    liwc_anger     0.106134
# 244                   tfidf_noth     0.102788
# 200                   tfidf_hurt     0.100715
# 250                   tfidf_pain     0.098610
# 67         liwc_negative_emotion     0.096785
# 336                   tfidf_wish     0.093590
# 187                  tfidf_happi     0.088090
# 143                tfidf_depress     0.086817
# 99                    tfidf_alon     0.086353
# 33      liwc_affective_processes     0.086057
# 19                      sent_pos     0.084556
# 223                   tfidf_love     0.084164
# 316                   tfidf_tire     0.082637
# 265                   tfidf_ptsd     0.080473
# 189                   tfidf_hate     0.074947
# 151                   tfidf_dont     0.074712
# 285                   tfidf_shit     0.074294
# 290                 tfidf_someon     0.074094
# 24                    guns_total     0.074010
# 164                tfidf_everyth     0.071987
# 49                   liwc_family     0.071720
# 4                 gulpease_index     0.071330
# 66                liwc_negations     0.071097
# 239                  tfidf_never     0.068349
# 306                   tfidf_talk     0.068202
# 249                   tfidf_onli     0.067173
# 202                     tfidf_im     0.066469
# 334                    tfidf_whi     0.065735
# 208                   tfidf_know     0.065229
# 163                tfidf_everyon     0.063033
# 53             liwc_future_tense     0.060849
# 255                  tfidf_peopl     0.060704
# 124                 tfidf_better     0.060136
# 272                 tfidf_reason     0.059964
# 42                liwc_certainty     0.059850
# 252                 tfidf_parent     0.059178
# 73         liwc_positive_emotion     0.059027
# 25         domestic_stress_total     0.059018
# 248                    tfidf_one     0.057552
# 91                    tfidf_abus     0.056450
# 47              liwc_discrepancy     0.055620
# 259                  tfidf_point     0.055510
# 212                   tfidf_left     0.055205
# 72        liwc_personal_pronouns     0.054709
# 221                   tfidf_lost     0.050863
# 30                 liwc_3rd_pers     0.050833
# 3            flesch_reading_ease     0.049923
# 78                 liwc_religion     0.049666
# 197                   tfidf_hope     0.048774
# 161                   tfidf_ever     0.048220
# 140                    tfidf_cri     0.048170
# 293                  tfidf_sorri     0.048131
# 312                  tfidf_think     0.048049
# 168                   tfidf_feel     0.047025
# 234                    tfidf_mom     0.046606
# 75            liwc_present_tense     0.046146
# 57                   liwc_humans     0.044328
# 160                   tfidf_even     0.043393
# 211                   tfidf_leav     0.042553
# 314                tfidf_thought     0.041883
# 180                     tfidf_go     0.041806
# 116                   tfidf_away     0.040830
# 342                  tfidf_would     0.040756
# 281                    tfidf_see     0.040349
# 44             liwc_common_verbs     0.038423
# 88           liwc_total_pronouns     0.038139
# 158                 tfidf_enough     0.037965
# 258                  tfidf_pleas     0.037251
# 307                   tfidf_tell     0.037083
# 82         liwc_social_processes     0.034966
# 329                    tfidf_way     0.033567
# 341                   tfidf_wors     0.033459
# 205                   tfidf_keep     0.031984
# 123                   tfidf_best     0.031801
# 112                  tfidf_anyth     0.031517
# 256                 tfidf_person     0.031317
# 270                   tfidf_real     0.031163
# 169              tfidf_feel like     0.030187
# 231                 tfidf_mental     0.030104
# 13                       n_sents     0.029741
# 38          liwc_auxiliary_verbs     0.026672
# 32                  liwc_adverbs     0.025264
# 227                   tfidf_mayb     0.024909
# 283                   tfidf_self     0.024883
# 184                  tfidf_guess     0.024771
# 48                liwc_exclusive     0.023441
# 237                   tfidf_much     0.022479
# 279                  tfidf_scare     0.022372
# 50                     liwc_feel     0.022335
# 320                    tfidf_tri     0.022188
# 263                tfidf_probabl     0.022024
# 122                 tfidf_believ     0.020813
# 345                   tfidf_year     0.020310
# 274           tfidf_relationship     0.020029
# 213                    tfidf_let     0.019940
# 179                   tfidf_give     0.019323
# 11          n_monosyllable_words     0.019046
# 181                   tfidf_good     0.017820
# 71     liwc_perceptual_processes     0.017058
# 278                    tfidf_say     0.016993
# 318                   tfidf_told     0.016465
# 276                  tfidf_right     0.016156
# 100                tfidf_alreadi     0.015694
# 62                  liwc_insight     0.015555
# 228                   tfidf_mean     0.015424
# 80                      liwc_see     0.014957
# 87         liwc_total_functional     0.014919
# 162                  tfidf_everi     0.014344
# 156                   tfidf_emot     0.014331
# 257                  tfidf_place     0.013082
# 138                  tfidf_could     0.013012
# 55                     liwc_hear     0.012448
# 129                   tfidf_call     0.011609
# 309                tfidf_therapi     0.011445
# 43                liwc_cognitive     0.011372
# 51                  liwc_fillers     0.009080
# 64                    liwc_money     0.007843
# 343                  tfidf_wrong     0.007685
# 192                   tfidf_hear     0.007533
# 261                   tfidf_post     0.006481
# 310              tfidf_therapist     0.006212
# 199                   tfidf_hous     0.005939
# 16                       n_words     0.005695
# 302                tfidf_support     0.005429
# 246                    tfidf_old     0.005383
# 236                   tfidf_move     0.005253
# 106                  tfidf_anoth     0.004778
# 224                   tfidf_made     0.004060
# 150                   tfidf_done     0.003477
# 65                   liwc_motion     0.003439
# 226                   tfidf_mani     0.002186
# 190                   tfidf_head     0.001880
# 102                  tfidf_alway     0.001605
# 126                   tfidf_bodi     0.000405
# 321                   tfidf_turn     0.000378
# 113                 tfidf_around     0.000192
# 21         economic_stress_total    -0.000156
# 225                   tfidf_make    -0.000161
# 28                 liwc_1st_pers    -0.000754
# 37                   liwc_assent    -0.001622
# 215                   tfidf_like    -0.001964
# 296                  tfidf_still    -0.001975
# 134                   tfidf_come    -0.002033
# 186                 tfidf_happen    -0.002328
# 130                   tfidf_came    -0.002391
# 118                    tfidf_bad    -0.002594
# 119                 tfidf_becaus    -0.002757
# 254                   tfidf_past    -0.004118
# 232                  tfidf_might    -0.004296
# 220                   tfidf_lose    -0.004690
# 196                   tfidf_home    -0.006234
# 76              liwc_quantifiers    -0.006332
# 69                  liwc_numbers    -0.006613
# 209                   tfidf_last    -0.007344
# 172                   tfidf_find    -0.007507
# 70               liwc_past_tense    -0.007681
# 120                  tfidf_becom    -0.007751
# 170                   tfidf_felt    -0.007828
# 313                 tfidf_though    -0.008143
# 295                   tfidf_stay    -0.008195
# 219                   tfidf_look    -0.008552
# 171                  tfidf_final    -0.008674
# 324                     tfidf_us    -0.008821
# 58      liwc_impersonal_pronouns    -0.009182
# 282                   tfidf_seem    -0.010104
# 14                   n_syllables    -0.010113
# 204                    tfidf_job    -0.010150
# 74             liwc_prepositions    -0.010488
# 59                liwc_inclusive    -0.010550
# 9                        n_chars    -0.010852
# 61               liwc_inhibition    -0.010863
# 271                 tfidf_realli    -0.011210
# 323             tfidf_understand    -0.011353
# 280                 tfidf_school    -0.011977
# 136               tfidf_constant    -0.012920
# 331                 tfidf_weight    -0.012991
# 92                  tfidf_actual    -0.013822
# 247                    tfidf_onc    -0.013932
# 117                   tfidf_back    -0.014775
# 233                   tfidf_mind    -0.015054
# 253                   tfidf_part    -0.015150
# 83                    liwc_space    -0.015401
# 335                  tfidf_whole    -0.015405
# 45             liwc_conjunctions    -0.015531
# 286                   tfidf_sinc    -0.015649
# 98                  tfidf_almost    -0.016013
# 188                   tfidf_hard    -0.016171
# 218                   tfidf_long    -0.016216
# 207                   tfidf_kind    -0.016288
# 133                  tfidf_chang    -0.016364
# 96                     tfidf_ago    -0.016784
# 191                 tfidf_health    -0.017189
# 242                  tfidf_night    -0.017309
# 266                    tfidf_put    -0.017433
# 15                n_unique_words    -0.017563
# 27                   punctuation    -0.018371
# 56                     liwc_home    -0.018408
# 297                   tfidf_stop    -0.018776
# 289                 tfidf_social    -0.019244
# 303                   tfidf_sure    -0.020361
# 39               liwc_biological    -0.021596
# 127                    tfidf_bpd    -0.021961
# 77               liwc_relativity    -0.022324
# 277                   tfidf_said    -0.022770
# 40                     liwc_body    -0.022892
# 260                tfidf_possibl    -0.023187
# 132                   tfidf_caus    -0.024393
# 29                 liwc_2nd_pers    -0.024909
# 216                  tfidf_littl    -0.025467
# 284                  tfidf_sever    -0.025809
# 210                   tfidf_late    -0.026185
# 139                  tfidf_coupl    -0.026516
# 288                  tfidf_sleep    -0.026694
# 135                tfidf_complet    -0.027384
# 292                tfidf_sometim    -0.027401
# 241                   tfidf_next    -0.027939
# 311                  tfidf_thing    -0.028405
# 174                   tfidf_food    -0.028726
# 287                 tfidf_situat    -0.029276
# 167                   tfidf_fear    -0.029780
# 175                  tfidf_found    -0.029989
# 147                 tfidf_disord    -0.030060
# 275                 tfidf_rememb    -0.030098
# 337                tfidf_without    -0.030793
# 262                 tfidf_pretti    -0.030880
# 86                     liwc_time    -0.031005
# 238                   tfidf_need    -0.031472
# 142                   tfidf_deal    -0.031581
# 185                    tfidf_guy    -0.031650
# 201                   tfidf_idea    -0.032943
# 36         liwc_articles_article    -0.032988
# 114                    tfidf_ask    -0.033864
# 182                    tfidf_got    -0.033983
# 121                  tfidf_befor    -0.034394
# 317                  tfidf_today    -0.034398
# 193                  tfidf_heart    -0.035522
# 154                    tfidf_eat    -0.036772
# 315                   tfidf_time    -0.036958
# 183                  tfidf_great    -0.037123
# 104              tfidf_amp x200b    -0.037975
# 344                  tfidf_x200b    -0.037975
# 322                    tfidf_two    -0.038119
# 194                   tfidf_help    -0.038169
# 300                  tfidf_stuff    -0.038525
# 125                    tfidf_bit    -0.038541
# 332                   tfidf_well    -0.040307
# 1             coleman_liau_index    -0.040980
# 85                liwc_tentative    -0.043223
# 68             liwc_nonfluencies    -0.043394
# 90                     tfidf_abl    -0.043485
# 333                   tfidf_went    -0.043976
# 327                   tfidf_veri    -0.044033
# 103                    tfidf_amp    -0.045033
# 235                  tfidf_month    -0.045188
# 54                   liwc_health    -0.045995
# 195                   tfidf_high    -0.046496
# 31              liwc_achievement    -0.046798
# 240                    tfidf_new    -0.048239
# 222                    tfidf_lot    -0.048438
# 298                 tfidf_stress    -0.049605
# 110                  tfidf_anyon    -0.049690
# 0    automated_readability_index    -0.050022
# 41                liwc_causation    -0.051595
# 155                    tfidf_els    -0.053051
# 319                   tfidf_took    -0.053866
# 273                 tfidf_recent    -0.054145
# 291                 tfidf_someth    -0.054794
# 146                 tfidf_differ    -0.055540
# 137                tfidf_control    -0.055813
# 10                  n_long_words    -0.056260
# 243                 tfidf_normal    -0.058112
# 338                 tfidf_wonder    -0.059093
# 299                tfidf_struggl    -0.059790
# 141                    tfidf_day    -0.061312
# 264                tfidf_problem    -0.061385
# 2     flesch_kincaid_grade_level    -0.062135
# 159                    tfidf_etc    -0.063743
# 267               tfidf_question    -0.064052
# 340                  tfidf_worri    -0.065115
# 153                   tfidf_drug    -0.065149
# 326                  tfidf_usual    -0.066378
# 268                   tfidf_quit    -0.067452
# 269                   tfidf_read    -0.067563
# 308                  tfidf_thank    -0.069292
# 325                    tfidf_use    -0.069450
# 63                  liwc_leisure    -0.071496
# 245                  tfidf_notic    -0.072610
# 178                    tfidf_get    -0.073310
# 128                  tfidf_brain    -0.074293
# 173                  tfidf_first    -0.076838
# 111              tfidf_anyon els    -0.076876
# 203                   tfidf_issu    -0.080758
# 149                    tfidf_doe    -0.083027
# 330                   tfidf_week    -0.084592
# 105                    tfidf_ani    -0.086273
# 165                 tfidf_experi    -0.086599
# 101                   tfidf_also    -0.087178
# 97                 tfidf_alcohol    -0.088056
# 12          n_polysyllable_words    -0.088432
# 304                tfidf_symptom    -0.088707
# 35                  liwc_anxiety    -0.089090
# 198                   tfidf_hour    -0.090943
# 95                   tfidf_advic    -0.095442
# 60                liwc_ingestion    -0.100835
# 251                  tfidf_panic    -0.100993
# 89                     liwc_work    -0.104483
# 115                 tfidf_attack    -0.104973
# 152                  tfidf_drink    -0.110534
# 305                   tfidf_take    -0.113969
# 294                  tfidf_start    -0.114883
# 339                   tfidf_work    -0.114929
# 148                 tfidf_doctor    -0.115501
# 108                tfidf_anxious    -0.127891
# 229                    tfidf_med    -0.131915
# 23           substance_use_total    -0.131978
# 144                tfidf_diagnos    -0.135169
# 20                 sent_compound    -0.147497
# 230                  tfidf_medic    -0.152593
# 93                  tfidf_addict    -0.166933
# 5              gunning_fog_index    -0.202034
# 6                            lix    -0.205970
# 7                     smog_index    -0.230303
# 107                tfidf_anxieti    -0.232619
# 8          wiener_sachtextformel    -0.238629
# 18                      sent_neu    -0.287691
# 94                    tfidf_adhd    -0.347325

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Read the CSV file
combined_df = pd.read_csv('./combined_df.csv')

# %%
combined_df.drop(columns=['post'], inplace=True)

# %%
import pandas as pd
from scipy.stats import f_oneway

# Calculate the Anova F-statistic for each feature
f_statistics = {}
for column in combined_df.columns:
    if column != 'subreddit':  # Skip the target variable
        groups = [combined_df[column][combined_df['subreddit'] == label] for label in combined_df['subreddit'].unique()]
        f_statistic, _ = f_oneway(*groups)
        f_statistics[column] = f_statistic

# Sort the F-statistics in descending order
sorted_f_statistics = dict(sorted(f_statistics.items(), key=lambda item: item[1], reverse=True))

# Print the sorted F-statistics
for feature, f_statistic in sorted_f_statistics.items():
    print(f'F-statistic between "subreddit" and "{feature}": {f_statistic:.2f}')
# Out:
# F-statistic between "subreddit" and "tfidf_adhd": 20799.19
# F-statistic between "subreddit" and "tfidf_anxieti": 19598.15
# F-statistic between "subreddit" and "tfidf_addict": 18865.69
# F-statistic between "subreddit" and "tfidf_ptsd": 18011.20
# F-statistic between "subreddit" and "tfidf_drink": 16796.50
# F-statistic between "subreddit" and "tfidf_bpd": 16726.12
# F-statistic between "subreddit" and "tfidf_alcohol": 12247.04
# F-statistic between "subreddit" and "substance_use_total": 7558.22
# F-statistic between "subreddit" and "sent_neu": 6330.74
# F-statistic between "subreddit" and "liwc_ingestion": 6225.05
# F-statistic between "subreddit" and "tfidf_depress": 5834.15
# F-statistic between "subreddit" and "sent_neg": 5587.82
# F-statistic between "subreddit" and "isolation_total": 4970.82
# F-statistic between "subreddit" and "tfidf_attack": 4173.07
# F-statistic between "subreddit" and "tfidf_suicid": 3982.79
# F-statistic between "subreddit" and "tfidf_anxious": 3931.92
# F-statistic between "subreddit" and "tfidf_panic": 3676.09
# F-statistic between "subreddit" and "wiener_sachtextformel": 3640.42
# F-statistic between "subreddit" and "tfidf_kill": 3531.71
# F-statistic between "subreddit" and "tfidf_friend": 3301.20
# F-statistic between "subreddit" and "smog_index": 3194.48
# F-statistic between "subreddit" and "liwc_sadness": 3156.30
# F-statistic between "subreddit" and "tfidf_diagnos": 2795.46
# F-statistic between "subreddit" and "lix": 2757.87
# F-statistic between "subreddit" and "sent_compound": 2492.53
# F-statistic between "subreddit" and "tfidf_die": 2471.04
# F-statistic between "subreddit" and "gunning_fog_index": 2398.68
# F-statistic between "subreddit" and "tfidf_medic": 2186.43
# F-statistic between "subreddit" and "liwc_anxiety": 2047.93
# F-statistic between "subreddit" and "tfidf_med": 2016.14
# F-statistic between "subreddit" and "tfidf_life": 1977.45
# F-statistic between "subreddit" and "tfidf_drug": 1791.62
# F-statistic between "subreddit" and "tfidf_want": 1779.65
# F-statistic between "subreddit" and "liwc_leisure": 1741.75
# F-statistic between "subreddit" and "liwc_friends": 1655.99
# F-statistic between "subreddit" and "tfidf_anymor": 1645.78
# F-statistic between "subreddit" and "liwc_death": 1640.29
# F-statistic between "subreddit" and "tfidf_alon": 1609.81
# F-statistic between "subreddit" and "tfidf_feel": 1511.75
# F-statistic between "subreddit" and "tfidf_live": 1440.82
# F-statistic between "subreddit" and "tfidf_abus": 1397.16
# F-statistic between "subreddit" and "tfidf_symptom": 1271.10
# F-statistic between "subreddit" and "tfidf_talk": 1261.56
# F-statistic between "subreddit" and "tfidf_take": 1233.60
# F-statistic between "subreddit" and "sent_pos": 1215.30
# F-statistic between "subreddit" and "liwc_negative_emotion": 1190.64
# F-statistic between "subreddit" and "liwc_health": 1171.73
# F-statistic between "subreddit" and "tfidf_end": 1092.80
# F-statistic between "subreddit" and "tfidf_relationship": 1052.61
# F-statistic between "subreddit" and "tfidf_someon": 1035.15
# F-statistic between "subreddit" and "liwc_sexual": 1023.98
# F-statistic between "subreddit" and "liwc_work": 1022.00
# F-statistic between "subreddit" and "tfidf_fuck": 999.12
# F-statistic between "subreddit" and "liwc_biological": 987.39
# F-statistic between "subreddit" and "tfidf_happi": 975.43
# F-statistic between "subreddit" and "suicidality_total": 974.12
# F-statistic between "subreddit" and "tfidf_doctor": 912.57
# F-statistic between "subreddit" and "tfidf_worri": 877.34
# F-statistic between "subreddit" and "liwc_affective_processes": 849.32
# F-statistic between "subreddit" and "liwc_swear_words": 842.49
# F-statistic between "subreddit" and "liwc_feel": 822.66
# F-statistic between "subreddit" and "tfidf_hear": 802.40
# F-statistic between "subreddit" and "tfidf_care": 796.80
# F-statistic between "subreddit" and "tfidf_quit": 795.56
# F-statistic between "subreddit" and "tfidf_fear": 760.17
# F-statistic between "subreddit" and "liwc_anger": 759.21
# F-statistic between "subreddit" and "tfidf_work": 742.77
# F-statistic between "subreddit" and "tfidf_peopl": 726.89
# F-statistic between "subreddit" and "tfidf_love": 709.98
# F-statistic between "subreddit" and "tfidf_noth": 701.67
# F-statistic between "subreddit" and "tfidf_experi": 692.47
# F-statistic between "subreddit" and "tfidf_famili": 688.06
# F-statistic between "subreddit" and "liwc_body": 644.00
# F-statistic between "subreddit" and "domestic_stress_total": 641.50
# F-statistic between "subreddit" and "tfidf_start": 632.08
# F-statistic between "subreddit" and "n_polysyllable_words": 627.25
# F-statistic between "subreddit" and "tfidf_pain": 619.62
# F-statistic between "subreddit" and "tfidf_emot": 600.25
# F-statistic between "subreddit" and "tfidf_anyon els": 587.01
# F-statistic between "subreddit" and "tfidf_advic": 573.13
# F-statistic between "subreddit" and "tfidf_hurt": 560.95
# F-statistic between "subreddit" and "tfidf_doe": 555.69
# F-statistic between "subreddit" and "tfidf_feel like": 536.04
# F-statistic between "subreddit" and "tfidf_stress": 526.32
# F-statistic between "subreddit" and "liwc_positive_emotion": 514.05
# F-statistic between "subreddit" and "tfidf_use": 506.18
# F-statistic between "subreddit" and "tfidf_happen": 502.56
# F-statistic between "subreddit" and "tfidf_also": 496.41
# F-statistic between "subreddit" and "liwc_hear": 484.56
# F-statistic between "subreddit" and "liwc_family": 484.10
# F-statistic between "subreddit" and "tfidf_wish": 482.68
# F-statistic between "subreddit" and "tfidf_shit": 482.01
# F-statistic between "subreddit" and "tfidf_hour": 476.72
# F-statistic between "subreddit" and "tfidf_ani": 470.58
# F-statistic between "subreddit" and "tfidf_anyon": 468.10
# F-statistic between "subreddit" and "tfidf_disord": 467.36
# F-statistic between "subreddit" and "tfidf_therapi": 463.18
# F-statistic between "subreddit" and "tfidf_heart": 462.27
# F-statistic between "subreddit" and "tfidf_question": 459.95
# F-statistic between "subreddit" and "tfidf_hate": 456.66
# F-statistic between "subreddit" and "liwc_social_processes": 450.65
# F-statistic between "subreddit" and "tfidf_everyth": 448.93
# F-statistic between "subreddit" and "liwc_humans": 437.96
# F-statistic between "subreddit" and "tfidf_social": 437.75
# F-statistic between "subreddit" and "tfidf_night": 434.82
# F-statistic between "subreddit" and "tfidf_person": 434.01
# F-statistic between "subreddit" and "tfidf_day": 433.42
# F-statistic between "subreddit" and "tfidf_brain": 429.21
# F-statistic between "subreddit" and "liwc_perceptual_processes": 422.96
# F-statistic between "subreddit" and "tfidf_tire": 419.36
# F-statistic between "subreddit" and "tfidf_cri": 409.85
# F-statistic between "subreddit" and "tfidf_week": 404.19
# F-statistic between "subreddit" and "liwc_achievement": 398.98
# F-statistic between "subreddit" and "tfidf_scare": 394.54
# F-statistic between "subreddit" and "tfidf_read": 389.17
# F-statistic between "subreddit" and "tfidf_like": 386.73
# F-statistic between "subreddit" and "tfidf_go": 382.10
# F-statistic between "subreddit" and "tfidf_therapist": 380.41
# F-statistic between "subreddit" and "n_long_words": 380.19
# F-statistic between "subreddit" and "tfidf_parent": 376.69
# F-statistic between "subreddit" and "tfidf_stop": 367.99
# F-statistic between "subreddit" and "tfidf_thank": 365.94
# F-statistic between "subreddit" and "tfidf_issu": 361.38
# F-statistic between "subreddit" and "liwc_personal_pronouns": 358.77
# F-statistic between "subreddit" and "liwc_present_tense": 351.77
# F-statistic between "subreddit" and "liwc_negations": 350.70
# F-statistic between "subreddit" and "tfidf_better": 349.74
# F-statistic between "subreddit" and "tfidf_school": 344.07
# F-statistic between "subreddit" and "guns_total": 335.03
# F-statistic between "subreddit" and "liwc_insight": 328.41
# F-statistic between "subreddit" and "tfidf_els": 324.94
# F-statistic between "subreddit" and "tfidf_know": 322.06
# F-statistic between "subreddit" and "liwc_time": 314.48
# F-statistic between "subreddit" and "liwc_future_tense": 310.30
# F-statistic between "subreddit" and "tfidf_differ": 309.19
# F-statistic between "subreddit" and "tfidf_wonder": 308.14
# F-statistic between "subreddit" and "liwc_common_verbs": 306.84
# F-statistic between "subreddit" and "tfidf_get": 306.32
# F-statistic between "subreddit" and "tfidf_control": 305.72
# F-statistic between "subreddit" and "liwc_causation": 305.04
# F-statistic between "subreddit" and "tfidf_never": 304.65
# F-statistic between "subreddit" and "liwc_inhibition": 304.37
# F-statistic between "subreddit" and "gulpease_index": 297.81
# F-statistic between "subreddit" and "tfidf_done": 297.14
# F-statistic between "subreddit" and "tfidf_notic": 294.49
# F-statistic between "subreddit" and "liwc_total_pronouns": 293.84
# F-statistic between "subreddit" and "tfidf_dont": 291.99
# F-statistic between "subreddit" and "tfidf_self": 291.32
# F-statistic between "subreddit" and "liwc_fillers": 290.71
# F-statistic between "subreddit" and "liwc_certainty": 287.17
# F-statistic between "subreddit" and "liwc_discrepancy": 281.47
# F-statistic between "subreddit" and "tfidf_help": 279.50
# F-statistic between "subreddit" and "tfidf_even": 277.61
# F-statistic between "subreddit" and "tfidf_understand": 277.42
# F-statistic between "subreddit" and "tfidf_old": 277.01
# F-statistic between "subreddit" and "tfidf_took": 275.81
# F-statistic between "subreddit" and "tfidf_first": 272.20
# F-statistic between "subreddit" and "tfidf_one": 256.36
# F-statistic between "subreddit" and "n_unique_words": 255.40
# F-statistic between "subreddit" and "liwc_adverbs": 254.75
# F-statistic between "subreddit" and "tfidf_bad": 254.67
# F-statistic between "subreddit" and "tfidf_onli": 253.77
# F-statistic between "subreddit" and "tfidf_whi": 253.37
# F-statistic between "subreddit" and "tfidf_lost": 252.50
# F-statistic between "subreddit" and "tfidf_rememb": 252.34
# F-statistic between "subreddit" and "liwc_relativity": 247.46
# F-statistic between "subreddit" and "tfidf_veri": 246.97
# F-statistic between "subreddit" and "liwc_motion": 245.14
# F-statistic between "subreddit" and "tfidf_struggl": 244.56
# F-statistic between "subreddit" and "tfidf_high": 244.06
# F-statistic between "subreddit" and "tfidf_problem": 242.75
# F-statistic between "subreddit" and "tfidf_year": 240.72
# F-statistic between "subreddit" and "liwc_past_tense": 238.64
# F-statistic between "subreddit" and "tfidf_im": 230.36
# F-statistic between "subreddit" and "tfidf_normal": 229.99
# F-statistic between "subreddit" and "tfidf_reason": 229.49
# F-statistic between "subreddit" and "tfidf_usual": 228.71
# F-statistic between "subreddit" and "tfidf_job": 227.81
# F-statistic between "subreddit" and "tfidf_new": 226.36
# F-statistic between "subreddit" and "tfidf_someth": 224.69
# F-statistic between "subreddit" and "tfidf_wors": 224.08
# F-statistic between "subreddit" and "flesch_kincaid_grade_level": 223.53
# F-statistic between "subreddit" and "tfidf_point": 223.28
# F-statistic between "subreddit" and "tfidf_anyth": 221.57
# F-statistic between "subreddit" and "n_monosyllable_words": 220.31
# F-statistic between "subreddit" and "tfidf_etc": 217.79
# F-statistic between "subreddit" and "liwc_auxiliary_verbs": 215.72
# F-statistic between "subreddit" and "tfidf_sleep": 215.49
# F-statistic between "subreddit" and "liwc_1st_pers": 212.93
# F-statistic between "subreddit" and "tfidf_thought": 209.43
# F-statistic between "subreddit" and "tfidf_month": 209.05
# F-statistic between "subreddit" and "tfidf_everyon": 208.87
# F-statistic between "subreddit" and "tfidf_think": 206.58
# F-statistic between "subreddit" and "liwc_total_functional": 206.39
# F-statistic between "subreddit" and "liwc_articles_article": 205.35
# F-statistic between "subreddit" and "liwc_money": 204.37
# F-statistic between "subreddit" and "n_sents": 204.12
# F-statistic between "subreddit" and "tfidf_deal": 203.94
# F-statistic between "subreddit" and "liwc_impersonal_pronouns": 203.14
# F-statistic between "subreddit" and "tfidf_thing": 199.74
# F-statistic between "subreddit" and "liwc_conjunctions": 199.07
# F-statistic between "subreddit" and "liwc_cognitive": 198.99
# F-statistic between "subreddit" and "tfidf_recent": 198.71
# F-statistic between "subreddit" and "economic_stress_total": 198.02
# F-statistic between "subreddit" and "liwc_inclusive": 197.50
# F-statistic between "subreddit" and "liwc_tentative": 195.35
# F-statistic between "subreddit" and "tfidf_mental": 194.94
# F-statistic between "subreddit" and "n_words": 194.82
# F-statistic between "subreddit" and "n_syllables": 192.71
# F-statistic between "subreddit" and "n_chars": 190.92
# F-statistic between "subreddit" and "tfidf_guy": 184.53
# F-statistic between "subreddit" and "tfidf_leav": 182.14
# F-statistic between "subreddit" and "tfidf_situat": 174.71
# F-statistic between "subreddit" and "tfidf_mom": 172.92
# F-statistic between "subreddit" and "liwc_prepositions": 168.12
# F-statistic between "subreddit" and "liwc_home": 168.04
# F-statistic between "subreddit" and "liwc_3rd_pers": 165.47
# F-statistic between "subreddit" and "tfidf_believ": 163.17
# F-statistic between "subreddit" and "tfidf_left": 162.46
# F-statistic between "subreddit" and "tfidf_bodi": 161.35
# F-statistic between "subreddit" and "tfidf_lot": 161.08
# F-statistic between "subreddit" and "tfidf_ever": 160.76
# F-statistic between "subreddit" and "automated_readability_index": 159.41
# F-statistic between "subreddit" and "liwc_space": 157.73
# F-statistic between "subreddit" and "liwc_religion": 157.43
# F-statistic between "subreddit" and "tfidf_befor": 156.78
# F-statistic between "subreddit" and "liwc_exclusive": 156.74
# F-statistic between "subreddit" and "tfidf_support": 156.40
# F-statistic between "subreddit" and "tfidf_went": 155.64
# F-statistic between "subreddit" and "tfidf_would": 154.81
# F-statistic between "subreddit" and "tfidf_real": 154.03
# F-statistic between "subreddit" and "tfidf_caus": 150.02
# F-statistic between "subreddit" and "flesch_reading_ease": 149.40
# F-statistic between "subreddit" and "tfidf_amp": 147.87
# F-statistic between "subreddit" and "tfidf_head": 145.96
# F-statistic between "subreddit" and "tfidf_constant": 145.62
# F-statistic between "subreddit" and "tfidf_sever": 143.51
# F-statistic between "subreddit" and "punctuation": 142.84
# F-statistic between "subreddit" and "tfidf_final": 142.35
# F-statistic between "subreddit" and "tfidf_enough": 135.75
# F-statistic between "subreddit" and "tfidf_sometim": 132.14
# F-statistic between "subreddit" and "tfidf_pleas": 131.65
# F-statistic between "subreddit" and "tfidf_away": 130.36
# F-statistic between "subreddit" and "tfidf_health": 129.19
# F-statistic between "subreddit" and "liwc_see": 128.75
# F-statistic between "subreddit" and "tfidf_back": 126.07
# F-statistic between "subreddit" and "tfidf_felt": 125.85
# F-statistic between "subreddit" and "tfidf_hope": 125.31
# F-statistic between "subreddit" and "tfidf_past": 123.70
# F-statistic between "subreddit" and "tfidf_ask": 123.24
# F-statistic between "subreddit" and "tfidf_abl": 120.82
# F-statistic between "subreddit" and "tfidf_said": 119.87
# F-statistic between "subreddit" and "liwc_nonfluencies": 119.28
# F-statistic between "subreddit" and "tfidf_tell": 117.54
# F-statistic between "subreddit" and "tfidf_last": 117.46
# F-statistic between "subreddit" and "tfidf_see": 114.68
# F-statistic between "subreddit" and "tfidf_keep": 114.60
# F-statistic between "subreddit" and "tfidf_good": 113.81
# F-statistic between "subreddit" and "coleman_liau_index": 113.23
# F-statistic between "subreddit" and "tfidf_everi": 109.50
# F-statistic between "subreddit" and "tfidf_without": 108.45
# F-statistic between "subreddit" and "tfidf_realli": 107.86
# F-statistic between "subreddit" and "tfidf_amp x200b": 107.62
# F-statistic between "subreddit" and "tfidf_x200b": 107.62
# F-statistic between "subreddit" and "tfidf_way": 107.52
# F-statistic between "subreddit" and "tfidf_sorri": 107.33
# F-statistic between "subreddit" and "tfidf_stuff": 105.51
# F-statistic between "subreddit" and "tfidf_found": 105.32
# F-statistic between "subreddit" and "tfidf_look": 104.71
# F-statistic between "subreddit" and "tfidf_told": 102.32
# F-statistic between "subreddit" and "tfidf_ago": 101.87
# F-statistic between "subreddit" and "tfidf_becaus": 100.63
# F-statistic between "subreddit" and "tfidf_eat": 98.66
# F-statistic between "subreddit" and "tfidf_possibl": 97.50
# F-statistic between "subreddit" and "tfidf_make": 96.74
# F-statistic between "subreddit" and "liwc_quantifiers": 96.71
# F-statistic between "subreddit" and "tfidf_best": 96.31
# F-statistic between "subreddit" and "tfidf_time": 95.11
# F-statistic between "subreddit" and "tfidf_find": 94.53
# F-statistic between "subreddit" and "liwc_2nd_pers": 92.40
# F-statistic between "subreddit" and "tfidf_put": 88.41
# F-statistic between "subreddit" and "tfidf_two": 87.10
# F-statistic between "subreddit" and "tfidf_us": 83.92
# F-statistic between "subreddit" and "tfidf_well": 81.98
# F-statistic between "subreddit" and "tfidf_today": 81.29
# F-statistic between "subreddit" and "tfidf_idea": 80.70
# F-statistic between "subreddit" and "tfidf_mind": 78.80
# F-statistic between "subreddit" and "tfidf_bit": 78.49
# F-statistic between "subreddit" and "tfidf_need": 76.11
# F-statistic between "subreddit" and "tfidf_much": 75.88
# F-statistic between "subreddit" and "tfidf_actual": 75.24
# F-statistic between "subreddit" and "tfidf_home": 74.21
# F-statistic between "subreddit" and "tfidf_tri": 73.03
# F-statistic between "subreddit" and "tfidf_got": 71.85
# F-statistic between "subreddit" and "tfidf_say": 71.20
# F-statistic between "subreddit" and "tfidf_alway": 70.94
# F-statistic between "subreddit" and "tfidf_great": 64.16
# F-statistic between "subreddit" and "tfidf_next": 63.50
# F-statistic between "subreddit" and "tfidf_pretti": 63.09
# F-statistic between "subreddit" and "tfidf_sure": 62.68
# F-statistic between "subreddit" and "tfidf_wrong": 62.36
# F-statistic between "subreddit" and "tfidf_complet": 61.75
# F-statistic between "subreddit" and "tfidf_sinc": 59.90
# F-statistic between "subreddit" and "tfidf_hous": 58.29
# F-statistic between "subreddit" and "tfidf_late": 58.03
# F-statistic between "subreddit" and "tfidf_coupl": 57.25
# F-statistic between "subreddit" and "tfidf_stay": 56.63
# F-statistic between "subreddit" and "tfidf_alreadi": 56.01
# F-statistic between "subreddit" and "tfidf_guess": 55.18
# F-statistic between "subreddit" and "tfidf_kind": 54.78
# F-statistic between "subreddit" and "tfidf_mean": 54.45
# F-statistic between "subreddit" and "tfidf_might": 53.87
# F-statistic between "subreddit" and "tfidf_food": 53.01
# F-statistic between "subreddit" and "liwc_numbers": 52.95
# F-statistic between "subreddit" and "tfidf_mayb": 50.15
# F-statistic between "subreddit" and "tfidf_hard": 49.76
# F-statistic between "subreddit" and "tfidf_chang": 48.73
# F-statistic between "subreddit" and "tfidf_right": 47.14
# F-statistic between "subreddit" and "tfidf_littl": 44.26
# F-statistic between "subreddit" and "tfidf_give": 43.64
# F-statistic between "subreddit" and "liwc_assent": 43.63
# F-statistic between "subreddit" and "tfidf_come": 43.48
# F-statistic between "subreddit" and "tfidf_weight": 41.43
# F-statistic between "subreddit" and "tfidf_still": 41.38
# F-statistic between "subreddit" and "tfidf_lose": 40.74
# F-statistic between "subreddit" and "tfidf_almost": 40.66
# F-statistic between "subreddit" and "tfidf_probabl": 40.59
# F-statistic between "subreddit" and "tfidf_move": 40.40
# F-statistic between "subreddit" and "tfidf_call": 38.26
# F-statistic between "subreddit" and "tfidf_long": 37.83
# F-statistic between "subreddit" and "tfidf_becom": 34.32
# F-statistic between "subreddit" and "tfidf_let": 33.49
# F-statistic between "subreddit" and "tfidf_seem": 33.28
# F-statistic between "subreddit" and "tfidf_onc": 32.23
# F-statistic between "subreddit" and "tfidf_part": 32.13
# F-statistic between "subreddit" and "tfidf_mani": 30.21
# F-statistic between "subreddit" and "tfidf_came": 29.92
# F-statistic between "subreddit" and "tfidf_though": 22.27
# F-statistic between "subreddit" and "tfidf_whole": 20.25
# F-statistic between "subreddit" and "tfidf_place": 19.50
# F-statistic between "subreddit" and "tfidf_could": 18.89
# F-statistic between "subreddit" and "tfidf_around": 14.96
# F-statistic between "subreddit" and "tfidf_post": 10.17
# F-statistic between "subreddit" and "tfidf_anoth": 9.15
# F-statistic between "subreddit" and "tfidf_made": 8.65
# F-statistic between "subreddit" and "tfidf_turn": 7.15

# %%
# Filter features with F-statistic > 500
selected_features = [feature for feature, f_statistic in f_statistics.items() if f_statistic > 500]

# Create a new DataFrame with selected features
combined_reduced_df = combined_df[selected_features]

# Save the new DataFrame to a CSV file
combined_reduced_df.to_csv('combined_reduced.csv', index=False)

# %%
# remove all columns which have their name starting with 'tfidf_'
combined_reduced_df = combined_reduced_df.loc[:, ~combined_reduced_df.columns.str.startswith('tfidf_')]
# Save the new DataFrame to a CSV file
combined_reduced_df.to_csv('combined_reduced.csv', index=False)

# %%
combined_reduced_df.shape
# Out:
# (374499, 30)

# %%
# print all unique values in the 'subreddit' column
print(combined_df['subreddit'].unique())
# Out:
# ['addiction' 'adhd' 'alcoholism' 'anxiety' 'autism' 'bpd' 'depression'
#  'lonely' 'ptsd' 'schizophrenia' 'suicidewatch']

# %%
# drop subreddit_encoded column from combined_df
combined_df.drop(columns=['subreddit_encoded'], inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import optuna
import numpy as np

# drop the 'subreddit' column from combined_df and assign the result to X
X = combined_df.drop(columns=['subreddit'])

# assign the 'subreddit' column from combined_df to y
y = combined_df['subreddit']

# Split the data into training and testing sets (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Further split the training set into training and validation sets (50% training, 50% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=42)

def objective(trial):
    # Define the hyperparameters to optimize
    n_estimators = trial.suggest_int("n_estimators", 50, 500)
    max_depth = trial.suggest_int("max_depth", 5, 80)
    # min_samples_split = trial.suggest_float("min_samples_split", 0.1, 1.0)
    # min_samples_leaf = trial.suggest_float("min_samples_leaf", 0.1, 0.5)

    # Initialize the Random Forest Classifier with suggested hyperparameters
    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        criterion='entropy',
        # min_samples_split=min_samples_split,
        # min_samples_leaf=min_samples_leaf,
        class_weight='balanced_subsample',
        random_state=42
    )

    # Fit the classifier to the training data
    clf.fit(X_train, y_train)

    # Make predictions on the validation data
    y_val_pred = clf.predict(X_val)

    # Calculate accuracy
    accuracy = accuracy_score(y_val, y_val_pred)

    return accuracy

# Create an Optuna study for optimization
study = optuna.create_study(direction="maximize")

# Optimize the objective function
study.optimize(objective, n_trials=50)  # You can adjust the number of trials

# Get the best hyperparameters from the study
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# Initialize the Random Forest Classifier with the best hyperparameters
best_clf = RandomForestClassifier(
    n_estimators=best_params["n_estimators"],
    max_depth=best_params["max_depth"],
    # min_samples_split=best_params["min_samples_split"],
    # min_samples_leaf=best_params["min_samples_leaf"],
    class_weight='balanced_subsample',
    random_state=42
)
# Out:
# [I 2023-10-24 19:48:50,781] A new study created in memory with name: no-name-1f871dc4-553b-46ba-aa20-c14486bfacf1
# [I 2023-10-24 19:54:06,144] Trial 0 finished with value: 0.620316612626359 and parameters: {'n_estimators': 149, 'max_depth': 52}. Best is trial 0 with value: 0.620316612626359.
# [I 2023-10-24 20:07:44,402] Trial 1 finished with value: 0.6231089071142476 and parameters: {'n_estimators': 390, 'max_depth': 80}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:10:22,142] Trial 2 finished with value: 0.6154491703223346 and parameters: {'n_estimators': 76, 'max_depth': 68}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:24:53,523] Trial 3 finished with value: 0.622513827961091 and parameters: {'n_estimators': 418, 'max_depth': 49}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:32:19,695] Trial 4 finished with value: 0.6147930574098799 and parameters: {'n_estimators': 256, 'max_depth': 21}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:42:53,085] Trial 5 finished with value: 0.623063131794774 and parameters: {'n_estimators': 301, 'max_depth': 66}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:44:32,831] Trial 6 finished with value: 0.49840930764829294 and parameters: {'n_estimators': 113, 'max_depth': 9}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:53:09,015] Trial 7 finished with value: 0.6225748617203891 and parameters: {'n_estimators': 248, 'max_depth': 59}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 20:59:55,216] Trial 8 finished with value: 0.5017356475300401 and parameters: {'n_estimators': 470, 'max_depth': 9}. Best is trial 1 with value: 0.6231089071142476.
# [I 2023-10-24 21:15:29,402] Trial 9 finished with value: 0.6276330345222201 and parameters: {'n_estimators': 462, 'max_depth': 28}. Best is trial 9 with value: 0.6276330345222201.
# [I 2023-10-24 21:33:16,620] Trial 10 finished with value: 0.6245813465573146 and parameters: {'n_estimators': 495, 'max_depth': 32}. Best is trial 9 with value: 0.6276330345222201.
# [I 2023-10-24 21:49:49,345] Trial 11 finished with value: 0.6247568186152966 and parameters: {'n_estimators': 476, 'max_depth': 33}. Best is trial 9 with value: 0.6276330345222201.
# [I 2023-10-24 22:02:32,580] Trial 12 finished with value: 0.6234064466908259 and parameters: {'n_estimators': 364, 'max_depth': 34}. Best is trial 9 with value: 0.6276330345222201.
# [I 2023-10-24 22:17:36,054] Trial 13 finished with value: 0.6236658401678429 and parameters: {'n_estimators': 429, 'max_depth': 34}. Best is trial 9 with value: 0.6276330345222201.
# [I 2023-10-24 22:28:30,956] Trial 14 finished with value: 0.6277322143810795 and parameters: {'n_estimators': 349, 'max_depth': 24}. Best is trial 14 with value: 0.6277322143810795.
# [I 2023-10-24 22:38:00,608] Trial 15 finished with value: 0.6164562273507533 and parameters: {'n_estimators': 328, 'max_depth': 21}. Best is trial 14 with value: 0.6277322143810795.
# [I 2023-10-24 22:43:17,126] Trial 16 finished with value: 0.5885714285714285 and parameters: {'n_estimators': 202, 'max_depth': 18}. Best is trial 14 with value: 0.6277322143810795.
# [I 2023-10-24 22:55:39,797] Trial 17 finished with value: 0.6224909403013542 and parameters: {'n_estimators': 357, 'max_depth': 43}. Best is trial 14 with value: 0.6277322143810795.
# [I 2023-10-24 23:09:16,690] Trial 18 finished with value: 0.6282586305550257 and parameters: {'n_estimators': 428, 'max_depth': 25}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-24 23:16:28,074] Trial 19 finished with value: 0.5581613580011444 and parameters: {'n_estimators': 319, 'max_depth': 15}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-24 23:30:56,503] Trial 20 finished with value: 0.6232920083921419 and parameters: {'n_estimators': 417, 'max_depth': 42}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-24 23:48:22,201] Trial 21 finished with value: 0.6279610909784474 and parameters: {'n_estimators': 449, 'max_depth': 27}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-25 00:05:41,273] Trial 22 finished with value: 0.6277398436009918 and parameters: {'n_estimators': 377, 'max_depth': 24}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-25 00:10:14,145] Trial 23 finished with value: 0.467427045584589 and parameters: {'n_estimators': 439, 'max_depth': 5}. Best is trial 18 with value: 0.6282586305550257.
# [I 2023-10-25 00:26:09,731] Trial 24 finished with value: 0.6287926759488842 and parameters: {'n_estimators': 386, 'max_depth': 26}. Best is trial 24 with value: 0.6287926759488842.
# [I 2023-10-25 00:44:20,697] Trial 25 finished with value: 0.6232614915124929 and parameters: {'n_estimators': 417, 'max_depth': 41}. Best is trial 24 with value: 0.6287926759488842.
# [I 2023-10-25 00:55:29,871] Trial 26 finished with value: 0.5591836734693878 and parameters: {'n_estimators': 397, 'max_depth': 15}. Best is trial 24 with value: 0.6287926759488842.
# [I 2023-10-25 01:07:24,100] Trial 27 finished with value: 0.6268319664314324 and parameters: {'n_estimators': 286, 'max_depth': 29}. Best is trial 24 with value: 0.6287926759488842.
# [I 2023-10-25 01:27:30,344] Trial 28 finished with value: 0.6230097272553882 and parameters: {'n_estimators': 500, 'max_depth': 38}. Best is trial 24 with value: 0.6287926759488842.
# [I 2023-10-25 01:34:54,736] Trial 29 finished with value: 0.6220484455464429 and parameters: {'n_estimators': 214, 'max_depth': 49}. Best is trial 24 with value: 0.6287926759488842.

# %%
clf = RandomForestClassifier(n_estimators=100, class_weight='balanced_subsample', random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6301290609701825

# %%
max_depth = clf.estimators_[0].tree_.max_depth
print(max_depth)
# Out:
# 98

# %%
# Fit the best classifier to the entire training dataset
best_clf.fit(X_train, y_train)

# Make predictions on the test data
y_test_pred = best_clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_test_pred)
print(f'Test Accuracy: {accuracy:.2f}')

# Generate a classification report on the test data
class_report = classification_report(y_test, y_test_pred, zero_division=0)
print("Test Classification Report:\n", class_report)
# Out:
# Test Accuracy: 0.64
# Test Classification Report:
#                 precision    recall  f1-score   support
#
#     addiction       0.75      0.56      0.64      2270
#          adhd       0.69      0.78      0.74     13753
#    alcoholism       0.68      0.73      0.70      1737
#       anxiety       0.80      0.72      0.76     17178
#        autism       0.61      0.29      0.39      2634
#           bpd       0.91      0.49      0.64      7187
#    depression       0.55      0.70      0.62     35446
#        lonely       0.58      0.47      0.52      6961
#          ptsd       0.81      0.55      0.65      2631
# schizophrenia       0.66      0.14      0.23      2673
#  suicidewatch       0.59      0.58      0.59     19880
#
#      accuracy                           0.64    112350
#     macro avg       0.69      0.55      0.59    112350
#  weighted avg       0.65      0.64      0.63    112350

# %%
# print clf.feature_importances_ in descending order of importance 
feature_importances = pd.DataFrame(best_clf.feature_importances_, index = X_train.columns, columns=['importance']).sort_values('importance', ascending=False)
print(feature_importances)
# Out:
#                              importance
# tfidf_ptsd                     0.033360
# tfidf_addict                   0.030753
# tfidf_adhd                     0.030692
# tfidf_bpd                      0.029676
# tfidf_anxieti                  0.025313
# tfidf_drink                    0.018946
# tfidf_alcohol                  0.014629
# liwc_ingestion                 0.013829
# isolation_total                0.012952
# substance_use_total            0.012034
# sent_neu                       0.011648
# sent_neg                       0.011510
# coleman_liau_index             0.009752
# tfidf_depress                  0.009702
# suicidality_total              0.009169
# sent_compound                  0.008465
# wiener_sachtextformel          0.008017
# flesch_reading_ease            0.007915
# liwc_death                     0.007733
# lix                            0.007461
# automated_readability_index    0.007293
# sent_pos                       0.007254
# liwc_social_processes          0.006921
# flesch_kincaid_grade_level     0.006882
# tfidf_friend                   0.006750
# gulpease_index                 0.006698
# gunning_fog_index              0.006633
# smog_index                     0.006285
# liwc_health                    0.006006
# liwc_leisure                   0.005800
# liwc_biological                0.005792
# n_chars                        0.005569
# tfidf_drug                     0.005388
# n_syllables                    0.005372
# n_long_words                   0.005301
# punctuation                    0.005262
# n_unique_words                 0.005113
# liwc_relativity                0.005106
# n_words                        0.005067
# liwc_time                      0.004975
# n_monosyllable_words           0.004939
# liwc_total_functional          0.004933
# liwc_total_pronouns            0.004908
# liwc_cognitive                 0.004808
# tfidf_feel                     0.004802
# liwc_present_tense             0.004791
# tfidf_diagnos                  0.004769
# n_polysyllable_words           0.004754
# liwc_common_verbs              0.004728
# liwc_personal_pronouns         0.004706
# liwc_sadness                   0.004643
# liwc_auxiliary_verbs           0.004500
# liwc_prepositions              0.004486
# liwc_affective_processes       0.004448
# liwc_work                      0.004408
# liwc_conjunctions              0.004394
# liwc_negative_emotion          0.004306
# liwc_impersonal_pronouns       0.004256
# liwc_past_tense                0.004203
# tfidf_like                     0.004184
# liwc_perceptual_processes      0.004164
# liwc_inclusive                 0.004125
# liwc_adverbs                   0.004048
# liwc_articles_article          0.004009
# tfidf_suicid                   0.003981
# n_sents                        0.003969
# tfidf_anxious                  0.003952
# liwc_space                     0.003924
# tfidf_peopl                    0.003910
# liwc_positive_emotion          0.003837
# liwc_insight                   0.003781
# liwc_exclusive                 0.003709
# liwc_tentative                 0.003629
# tfidf_abus                     0.003619
# tfidf_get                      0.003603
# tfidf_know                     0.003548
# tfidf_attack                   0.003544
# liwc_negations                 0.003520
# tfidf_want                     0.003474
# liwc_friends                   0.003471
# tfidf_help                     0.003378
# tfidf_talk                     0.003355
# liwc_discrepancy               0.003325
# liwc_hear                      0.003282
# tfidf_life                     0.003265
# liwc_anxiety                   0.003228
# liwc_quantifiers               0.003181
# tfidf_go                       0.003143
# tfidf_day                      0.003109
# liwc_feel                      0.003049
# tfidf_kill                     0.003047
# liwc_causation                 0.003004
# tfidf_time                     0.002999
# liwc_family                    0.002960
# tfidf_someon                   0.002960
# liwc_achievement               0.002939
# tfidf_year                     0.002936
# tfidf_panic                    0.002922
# tfidf_take                     0.002909
# liwc_humans                    0.002889
# tfidf_ani                      0.002853
# liwc_motion                    0.002835
# tfidf_alon                     0.002829
# tfidf_anyon                    0.002809
# tfidf_med                      0.002733
# tfidf_think                    0.002704
# tfidf_symptom                  0.002663
# tfidf_becaus                   0.002662
# tfidf_realli                   0.002628
# tfidf_thing                    0.002548
# tfidf_one                      0.002543
# tfidf_make                     0.002507
# liwc_anger                     0.002493
# tfidf_medic                    0.002479
# liwc_2nd_pers                  0.002458
# liwc_body                      0.002457
# tfidf_use                      0.002412
# tfidf_someth                   0.002377
# tfidf_hear                     0.002370
# tfidf_even                     0.002363
# tfidf_tri                      0.002363
# liwc_certainty                 0.002330
# tfidf_need                     0.002325
# tfidf_happen                   0.002272
# tfidf_old                      0.002261
# liwc_3rd_pers                  0.002257
# tfidf_would                    0.002251
# liwc_future_tense              0.002241
# tfidf_start                    0.002227
# tfidf_feel like                0.002199
# tfidf_work                     0.002165
# liwc_inhibition                0.002164
# tfidf_stop                     0.002154
# tfidf_doe                      0.002109
# liwc_fillers                   0.002082
# tfidf_thought                  0.002063
# tfidf_quit                     0.002062
# liwc_see                       0.002000
# tfidf_also                     0.001974
# tfidf_see                      0.001969
# tfidf_els                      0.001962
# tfidf_veri                     0.001946
# tfidf_die                      0.001945
# tfidf_much                     0.001940
# liwc_numbers                   0.001924
# tfidf_onli                     0.001910
# liwc_sexual                    0.001905
# tfidf_live                     0.001894
# tfidf_person                   0.001886
# tfidf_say                      0.001881
# tfidf_back                     0.001879
# tfidf_relationship             0.001854
# tfidf_night                    0.001838
# tfidf_never                    0.001820
# tfidf_way                      0.001802
# tfidf_social                   0.001795
# tfidf_advic                    0.001788
# tfidf_got                      0.001782
# tfidf_week                     0.001755
# tfidf_month                    0.001752
# tfidf_thank                    0.001748
# tfidf_love                     0.001699
# liwc_1st_pers                  0.001672
# tfidf_good                     0.001669
# tfidf_lot                      0.001664
# tfidf_look                     0.001664
# domestic_stress_total          0.001657
# tfidf_anyth                    0.001649
# tfidf_still                    0.001630
# economic_stress_total          0.001629
# tfidf_last                     0.001624
# tfidf_tell                     0.001623
# tfidf_end                      0.001619
# tfidf_find                     0.001617
# tfidf_alway                    0.001605
# tfidf_bad                      0.001605
# tfidf_understand               0.001601
# tfidf_anymor                   0.001598
# tfidf_could                    0.001591
# tfidf_sinc                     0.001588
# tfidf_therapi                  0.001583
# liwc_money                     0.001570
# tfidf_high                     0.001511
# liwc_swear_words               0.001510
# tfidf_experi                   0.001508
# tfidf_everi                    0.001505
# tfidf_right                    0.001491
# tfidf_school                   0.001471
# tfidf_come                     0.001468
# tfidf_mental                   0.001464
# tfidf_real                     0.001458
# tfidf_famili                   0.001455
# tfidf_befor                    0.001436
# tfidf_first                    0.001434
# tfidf_hard                     0.001422
# tfidf_ago                      0.001407
# tfidf_emot                     0.001394
# tfidf_everyth                  0.001388
# liwc_home                      0.001380
# tfidf_fuck                     0.001373
# tfidf_keep                     0.001368
# tfidf_seem                     0.001365
# tfidf_ever                     0.001364
# tfidf_anyon els                0.001358
# tfidf_long                     0.001357
# tfidf_around                   0.001355
# tfidf_whi                      0.001354
# tfidf_well                     0.001346
# tfidf_better                   0.001335
# tfidf_therapist                0.001327
# tfidf_ask                      0.001320
# tfidf_today                    0.001285
# tfidf_new                      0.001274
# tfidf_everyon                  0.001272
# tfidf_head                     0.001268
# tfidf_recent                   0.001268
# tfidf_problem                  0.001267
# tfidf_parent                   0.001264
# tfidf_hope                     0.001261
# tfidf_told                     0.001234
# tfidf_away                     0.001219
# tfidf_without                  0.001218
# tfidf_post                     0.001207
# tfidf_sometim                  0.001206
# tfidf_sure                     0.001204
# tfidf_hate                     0.001200
# tfidf_guy                      0.001193
# tfidf_give                     0.001182
# tfidf_said                     0.001173
# tfidf_went                     0.001171
# tfidf_scare                    0.001171
# tfidf_almost                   0.001158
# tfidf_self                     0.001153
# tfidf_sleep                    0.001146
# tfidf_deal                     0.001144
# tfidf_noth                     0.001139
# tfidf_struggl                  0.001137
# tfidf_normal                   0.001135
# tfidf_two                      0.001130
# tfidf_mind                     0.001124
# tfidf_believ                   0.001120
# tfidf_issu                     0.001112
# tfidf_hurt                     0.001111
# tfidf_point                    0.001108
# tfidf_made                     0.001108
# tfidf_past                     0.001106
# tfidf_read                     0.001106
# tfidf_worri                    0.001106
# tfidf_question                 0.001097
# tfidf_pleas                    0.001081
# tfidf_wonder                   0.001077
# tfidf_mani                     0.001074
# tfidf_happi                    0.001062
# tfidf_differ                   0.001059
# tfidf_care                     0.001049
# tfidf_call                     0.001047
# tfidf_put                      0.001040
# tfidf_support                  0.001038
# tfidf_littl                    0.001038
# tfidf_doctor                   0.001034
# tfidf_place                    0.001022
# tfidf_best                     0.001019
# tfidf_im                       0.001018
# tfidf_abl                      0.001018
# tfidf_actual                   0.001012
# tfidf_rememb                   0.001011
# tfidf_let                      0.001008
# tfidf_though                   0.001007
# tfidf_pretti                   0.001006
# tfidf_eat                      0.001005
# tfidf_hour                     0.001003
# tfidf_job                      0.001001
# tfidf_kind                     0.000999
# tfidf_felt                     0.000986
# tfidf_mean                     0.000978
# tfidf_mayb                     0.000976
# tfidf_shit                     0.000976
# tfidf_home                     0.000974
# tfidf_done                     0.000968
# tfidf_disord                   0.000966
# tfidf_wors                     0.000964
# tfidf_leav                     0.000952
# tfidf_chang                    0.000945
# tfidf_caus                     0.000939
# tfidf_might                    0.000936
# tfidf_stay                     0.000925
# tfidf_lost                     0.000918
# tfidf_control                  0.000905
# tfidf_complet                  0.000901
# tfidf_cri                      0.000901
# tfidf_move                     0.000893
# tfidf_anoth                    0.000891
# tfidf_part                     0.000883
# tfidf_reason                   0.000871
# tfidf_sever                    0.000868
# tfidf_found                    0.000867
# liwc_nonfluencies              0.000859
# tfidf_great                    0.000858
# tfidf_constant                 0.000857
# tfidf_amp                      0.000856
# tfidf_onc                      0.000854
# tfidf_possibl                  0.000833
# tfidf_idea                     0.000827
# tfidf_pain                     0.000824
# liwc_assent                    0.000822
# tfidf_brain                    0.000821
# tfidf_took                     0.000821
# tfidf_wish                     0.000821
# tfidf_health                   0.000820
# tfidf_stuff                    0.000819
# tfidf_next                     0.000818
# liwc_religion                  0.000817
# tfidf_bit                      0.000815
# tfidf_turn                     0.000812
# tfidf_enough                   0.000811
# tfidf_final                    0.000807
# tfidf_hous                     0.000803
# tfidf_usual                    0.000795
# tfidf_becom                    0.000793
# tfidf_us                       0.000792
# tfidf_dont                     0.000787
# tfidf_situat                   0.000785
# tfidf_sorri                    0.000784
# tfidf_left                     0.000784
# tfidf_etc                      0.000778
# tfidf_wrong                    0.000777
# tfidf_fear                     0.000770
# tfidf_tire                     0.000769
# tfidf_guess                    0.000754
# tfidf_stress                   0.000738
# tfidf_coupl                    0.000730
# tfidf_alreadi                  0.000722
# tfidf_probabl                  0.000720
# tfidf_late                     0.000705
# tfidf_lose                     0.000691
# tfidf_mom                      0.000686
# tfidf_whole                    0.000685
# tfidf_bodi                     0.000654
# tfidf_came                     0.000654
# tfidf_notic                    0.000617
# tfidf_amp x200b                0.000549
# tfidf_heart                    0.000524
# tfidf_x200b                    0.000516
# tfidf_food                     0.000483
# tfidf_weight                   0.000444
# guns_total                     0.000289

# %%
# print number of entries for each type of value in the 'subreddit' column
print(combined_df['subreddit'].value_counts())
# Out:
# depression       117331
# suicidewatch      66161
# anxiety           57671
# adhd              45631
# bpd               24294
# lonely            23635
# autism             8869
# schizophrenia      8712
# ptsd               8643
# addiction          7641
# alcoholism         5911
# Name: subreddit, dtype: int64
